# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
plt.style.use('seaborn')

# %%
img =image.load_img("cody2.jpg",target_size=(100,100))
x = image.img_to_array(img)/255.0
plt.imshow(x)
plt.axis('off')
plt.show()

# %%
x = x.reshape((1,100,100,3))
datagen = ImageDataGenerator(rotation_range=30,shear_range=0.2,width_shift_range=0.2,height_shift_range=0.2,zoom_range=0.2,horizontal_flip=True,fill_mode="nearest")

# %%
for batch in datagen.flow(x,batch_size=1):
    plt.figure()
    plt.imshow(image_)
